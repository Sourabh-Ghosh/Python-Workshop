# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourabh-Ghosh/Python-Workshop/blob/main/Python_Workshop_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1)
# Out:
# 1
